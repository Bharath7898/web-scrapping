# %%
from googleapiclient.discovery import build
youTubeapikey = 'AIzaSyCSosjUZfWpQEhSVnKJNTaFyERtH2dhg2k'
youtube = build ('youtube','v3', developerKey = youTubeapikey)

allvideos = []
nextpage_token = None
res = youtube.search().list(type = 'video', q ='recipe_for_lunch', maxResults = 50, part = 'snippet', pageToken=nextpage_token).execute()
while 1:
    res = youtube.search().list(type = 'video', q ='recipe_for_lunch', maxResults = 50, part = 'snippet', pageToken=nextpage_token).execute()
    allvideos +=res['items']
    nextpage_token = res.get('nextPageToken')
    if nextpage_token is None:
        break

len(allvideos)
allvideos[110]

video_ids = list(map(lambda x:x['id']['videoId'], allvideos))
print(len(video_ids))
video_ids[1]
stats = []
for i in range(0,len(video_ids), 50):
    res = (youtube).videos().list(id = ','.join(video_ids[i:i+50]), part= 'statistics,contentDetails').execute()
    stats += res['items']
print (stats[377])
len(stats)

title = []
videoid = []
like = []
dislike = []
views = []
description = []

len(like)

for i in range(len(video_ids)):
    try:
        like.append(int(stats[i]['statistics']['likeCount']))
    except:
        like.append(0)

    try:
        dislike.append(int(stats[i]['statistics']['dislikeCount']))
    except:
        dislike.append(0)
        
    try:
        views.append(int(stats[i]['statistics']['viewCount']))
    except:
        views.append(0)
        
    description.append(allvideos[i]['snippet']['description'])
    
    videoid.append(allvideos[i]['id']['videoId'])

    title.append(allvideos[i]['snippet']['title'])


import pandas as pd
data = {'videoid':videoid,'views':views,'like':like, 'dislike':dislike,'description':description, 'title':title}
df = pd.DataFrame(data)
df.head(10)
df.info()
df.to_csv('recipe_for_lunch.csv')
# Out:
# 570
# {'kind': 'youtube#video', 'etag': 'y_2sLWdjXffC1wRFwM79qxtyfOs', 'id': '4M7Cm-RptV4', 'contentDetails': {'duration': 'PT10M2S', 'dimension': '2d', 'definition': 'sd', 'caption': 'true', 'licensedContent': True, 'contentRating': {}, 'projection': 'rectangular'}, 'statistics': {'viewCount': '328', 'likeCount': '72', 'favoriteCount': '0', 'commentCount': '216'}}
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   videoid      570 non-null    object
#  1   views        570 non-null    int64
#  2   like         570 non-null    int64
#  3   dislike      570 non-null    int64
#  4   description  570 non-null    object
#  5   title        570 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 26.8+ KB

# %%
df
# Out:
#          videoid    views   like  dislike  \
# 0    w0S_0cR9d_4      921      9        0
# 1    mNnMpBlQAoM    12140    256        0
# 2    RdmafPeGO-c  2374568  52970        0
# 3    X83aePgWCrM  4306025  62610        0
# 4    rM4ErpEiepU   134811   3175        0
# ..           ...      ...    ...      ...
# 565  3zwzz4039Cg      786     35        0
# 566  _gF9SIjqz_Q      202      5        0
# 567  rp0MvtYDVyM        1      0        0
# 568  GLV-4oNyhak       12      2        0
# 569  5A6Z_H8oZ0k        2      0        0
#
#                                            description  \
# 0    I didn't stop eating when I made this! When I ...
# 1    nammaadugenimmaruchi #kannadarecipes #ricereci...
# 2    6lunchBoxRiceRecipeBykabita #LunchBoxrecipeByK...
# 3    malai kofta recipe: https://hebbarskitchen.com...
# 4    high protein channa salad recipe for weight lo...
# ..                                                 ...
# 565  food #foodie #shorts #viralshorts #viral #reci...
# 566  food #foodie #shorts #viralshorts #viral #reci...
# 567  Aslam o Alikum everyone I am Lubna batool Welc...
# 568  food #foodie #shorts #viralshorts #viral #reci...
# 569  Aslam o Alikum everyone I am Lubna batool Welc...
#
#                                                  title
# 0    5 minutes recipe| Bread Snacks Recipe for lunc...
# 1    ಲಂಚ್ ಬಾಕ್ಸ್, ಬ್ರೇಕ್ ಫಾಸ್ಟ್ ಗೆ ದಿಡೀರ್ ರೈಸ್ ರೆಸಿ...
# 2    ६ आसान और झटपट राइस टिफिन के लिए |  Rice Recip...
# 3    malai kofta &amp; garlic naan recipe for lunch...
# 4    Weight Loss Salad Recipe For Lunch/Dinner - In...
# ..                                                 ...
# 565  #shorts #recipe #food #foodlover #streetfood #...
# 566  #shorts #food #recipe #foodlover #tasty #spicy...
# 567  How to make mutton | simple and delicious 😋 mu...
# 568  #payerecipe #food #recipe #foodie #foodlover #...
# 569  Bakry ka gosht recipe | yummy 😋 and tasty mutt...
#
# [570 rows x 6 columns]

# %%
\
